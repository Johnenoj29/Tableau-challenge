# %%
import pandas as pd

# %%
jan_file= "201701-citibike-tripdata.csv"
july_file= "201707-citibike-tripdata.csv"

# %%
jan_df = pd.read_csv(jan_file)
july_df = pd.read_csv(july_file)

# %%
jan_df.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
july_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
july_df.columns=['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
       'Start Station Name', 'Start Station Latitude',
       'Start Station Longitude', 'End Station ID', 'End Station Name',
       'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
       'Birth Year', 'Gender']

# %%
july_df.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
combined_df = pd.concat([jan_df,july_df])

# %%
combined_df.columns
# Out:
# Index(['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID',
#        'Start Station Name', 'Start Station Latitude',
#        'Start Station Longitude', 'End Station ID', 'End Station Name',
#        'End Station Latitude', 'End Station Longitude', 'Bike ID', 'User Type',
#        'Birth Year', 'Gender'],
#       dtype='object')

# %%
combined_df
# Out:
#          Trip Duration           Start Time            Stop Time  \
# 0                  680  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1                 1282  2017-01-01 00:00:45  2017-01-01 00:22:08
# 2                  648  2017-01-01 00:00:57  2017-01-01 00:11:46
# 3                  631  2017-01-01 00:01:10  2017-01-01 00:11:42
# 4                  621  2017-01-01 00:01:25  2017-01-01 00:11:47
# ...                ...                  ...                  ...
# 1735594            560  2017-07-31 23:59:33  2017-08-01 00:08:53
# 1735595            272  2017-07-31 23:59:35  2017-08-01 00:04:08
# 1735596           1211  2017-07-31 23:59:37  2017-08-01 00:19:49
# 1735597            547  2017-07-31 23:59:48  2017-08-01 00:08:56
# 1735598           1816  2017-07-31 23:59:57  2017-08-01 00:30:13
#
#          Start Station ID           Start Station Name  \
# 0                    3226  W 82 St & Central Park West
# 1                    3263       Cooper Square & E 7 St
# ...

# %%
combined_df.to_csv("citibike.csv",index =False)
